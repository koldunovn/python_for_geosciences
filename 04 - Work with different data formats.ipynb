# %% [markdown]
# # Work with different data formats (binary, netCDF, .mat)

# %% [markdown]
# Nikolay Koldunov
#
# koldunovn@gmail.com

# %% [markdown]
# This is part of [**Python for Geosciences**](https://github.com/koldunovn/python_for_geosciences) notes.

# %% [markdown]
# ================

# %% [markdown]
# ## Binary data

# %% [markdown]
# ### Open binary

# %% [markdown]
# Data from [Sea Ice Concentrations from Nimbus-7 SMMR and DMSP SSM/I-SSMIS Passive Microwave Data](http://nsidc.org/data/nsidc-0051.html).

# %%
# !wget ftp://sidads.colorado.edu/pub/DATASETS/nsidc0051_gsfc_nasateam_seaice/final-gsfc/north/monthly/nt_200709_f17_v01_n.bin

# %% [markdown]
# Create file id:

# %%
ice = fromfile('nt_200709_f17_v01_n.bin', dtype='uint8')

# %% [markdown]
# We use *uint8* data type.
# [List of numpy data types](http://docs.scipy.org/doc/numpy/user/basics.types.html)

# %% [markdown]
# The file format consists of a 300-byte descriptive header followed by a two-dimensional array.

# %%
ice = ice[300:]

# %% [markdown]
# Reshape

# %%
ice = ice.reshape(448,304)

# %% [markdown]
# Simple visualisation of array with imshow (Matplotlib function):

# %%
imshow(ice)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xb05bb2c>

# %% [markdown]
# To convert to the fractional parameter range of 0.0 to 1.0, divide the scaled data in the file by 250.

# %%
ice = ice/250.
imshow(ice)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xb20c50c>

# %% [markdown]
# Let's mask all land and missing values:

# %%
ice_masked = ma.masked_greater(ice, 1.0)
imshow(ice_masked)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xb2e79ac>

# %% [markdown]
# Masking in this case is similar to using *NaN* in Matlab. [More about NumPy masked arrays](http://docs.scipy.org/doc/numpy/reference/maskedarray.html)

# %% [markdown]
# ### Save binary

# %%
fid = open('My_ice_2007.bin', 'wb')
ice.tofile(fid)
fid.close()

# %% [markdown]
# In order to work with other data formats we need to use one of the SciPy submodules:

# %% [markdown]
# ## SciPy

# %% [markdown]
# <img  height="100" src="files/scipy.png" >

# %% [markdown]
# General purpose scientific library (that consist of bunch of sublibraries) and builds on NumPy arrays.
#
# * Special functions ([scipy.special](http://docs.scipy.org/doc/scipy/reference/special.html))
# * Integration ([scipy.integrate](http://docs.scipy.org/doc/scipy/reference/integrate.html))
# * Optimization ([scipy.optimize](http://docs.scipy.org/doc/scipy/reference/optimize.html))
# * Interpolation ([scipy.interpolate](http://docs.scipy.org/doc/scipy/reference/interpolate.html))
# * Fourier Transforms ([scipy.fftpack](http://docs.scipy.org/doc/scipy/reference/fftpack.html))
# * Signal Processing ([scipy.signal](http://docs.scipy.org/doc/scipy/reference/signal.html))
# * Linear Algebra ([scipy.linalg](http://docs.scipy.org/doc/scipy/reference/linalg.html))
# * Sparse Eigenvalue Problems ([scipy.sparse](http://docs.scipy.org/doc/scipy/reference/sparse.html))
# * Statistics ([scipy.stats](http://docs.scipy.org/doc/scipy/reference/stats.html))
# * Multi-dimensional image processing ([scipy.ndimage](http://docs.scipy.org/doc/scipy/reference/ndimage.html))
# * File IO ([scipy.io](http://docs.scipy.org/doc/scipy/reference/io.html))
#
# We are going to use only scipy.io library.

# %% [markdown]
# ## scipy.io

# %% [markdown]
# ### Open .mat files

# %% [markdown]
# First we have to load function that works with Matlab files:

# %%
from scipy.io import loadmat

# %% [markdown]
# We are going to download [Polar science center Hydrographic Climatology (PHC)](http://psc.apl.washington.edu/nonwp_projects/PHC/Climatology.html) for January in Matlab format.

# %%
# !wget https://www.dropbox.com/s/0kuzvz03gw6d393/PHC_jan.mat

# %% [markdown]
# Open file:

# %%
all_variables = loadmat('PHC_jan.mat')

# %% [markdown]
# We can look at the names of variables stored in the file:

# %%
all_variables.keys()
# Out:
# ['PTEMP1', 'LON', '__header__', '__globals__', 'DEPTH', 'LAT', '__version__']

# %% [markdown]
# We need only *PTEMP1* (3d potential temperature).

# %%
temp = numpy.array(all_variables['PTEMP1'])

# %% [markdown]
# Check variable's shape:

# %%
temp.shape
# Out:
# (33, 180, 360)

# %% [markdown]
# Show surface level:

# %%
imshow(temp[0,:,:])
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xb6383ac>

# %% [markdown]
# ### Open netCDF files

# %% [markdown]
# Import nessesary function:

# %%
from scipy.io import netcdf

# %% [markdown]
# I am going to download [NCEP reanalysis data](http://www.esrl.noaa.gov/psd/data/reanalysis/reanalysis.shtml). Surface 4 daily air temperature for 2012.

# %%
# !wget ftp://ftp.cdc.noaa.gov/Datasets/ncep.reanalysis/surface/air.sig995.2012.nc

#Alternative for the times of US goverment shutdowns:
#!wget http://database.rish.kyoto-u.ac.jp/arch/ncep/data/ncep.reanalysis/surface/air.sig995.2012.nc
# Out:
# --2013-10-27 00:19:39--  ftp://ftp.cdc.noaa.gov/Datasets/ncep.reanalysis/surface/air.sig995.2012.nc
#            => ‘air.sig995.2012.nc’
# Resolving ftp.cdc.noaa.gov (ftp.cdc.noaa.gov)...
# 140.172.38.117
# Connecting to ftp.cdc.noaa.gov (ftp.cdc.noaa.gov)|140.172.38.117|:21...
# connected.
# Logging in as anonymous ...
# Logged in!
# ==> SYST ...
# done.    ==> PWD ...
# done.
# ==> TYPE I ...
# done.  ==> CWD (1) /Datasets/ncep.reanalysis/surface ...
# done.
# ==> SIZE air.sig995.2012.nc ...
# 30793412
# ==> PASV ...
# done.    ==> RETR air.sig995.2012.nc ...
# done.
# Length: 30793412 (29M) (unauthoritative)
#
#  0% [                                       ] 0           --.-K/s
#  0% [                                       ] 21.600       104KB/s
#  0% [                                       ] 66.240       159KB/s
#  0% [                                       ] 120.960      195KB/s
#  0% [                                       ] 187.200      226KB/s
#  0% [                                       ] 288.000      278KB/s
#  1% [                                       ] 416.160      335KB/s
#  1% [                                       ] 603.360      415KB/s
#  2% [>                                      ] 856.800      515KB/s
#  3% [>                                      ] 1.069.920    570KB/s
#  4% [>                                      ] 1.270.080    448KB/s
#  4% [>                                      ] 1.307.520    406KB/s  eta 71s
#  4% [>                                      ] 1.513.440    421KB/s  eta 71s
#  6% [=>                                     ] 1.923.840    506KB/s  eta 71s
#  6% [=>                                     ] 1.985.760    495KB/s  eta 71s
#  6% [=>                                     ] 2.088.000    495KB/s  eta 71s
#  7% [=>                                     ] 2.239.200    506KB/s  eta 55s
#  7% [==>                                    ] 2.458.080    552KB/s  eta 55s
#  8% [==>                                    ] 2.711.520    619KB/s  eta 55s
#  9% [==>                                    ] 2.970.720    664KB/s  eta 55s
# 10% [===>                                   ] 3.227.040    703KB/s  eta 55s
# 11% [===>                                   ] 3.480.480    722KB/s  eta 42s
# 12% [===>                                   ] 3.739.680    742KB/s  eta 42s
# 12% [====>                                  ] 3.990.240    753KB/s  eta 42s
# 13% [====>                                  ] 4.249.440    750KB/s  eta 42s
# 14% [====>                                  ] 4.501.440    941KB/s  eta 42s
# 15% [=====>                                 ] 4.760.640   1011KB/s  eta 35s
# 16% [=====>                                 ] 5.011.200   1,10MB/s  eta 35s
# 17% [=====>                                 ] 5.268.960   1,12MB/s  eta 35s
# 17% [=====>                                 ] 5.522.400   1,17MB/s  eta 35s
# 18% [======>                                ] 5.777.280   1,17MB/s  eta 35s
# 19% [======>                                ] 6.033.600   1,20MB/s  eta 30s
# 20% [======>                                ] 6.289.920   1,20MB/s  eta 30s
# 21% [=======>                               ] 6.540.480   1,21MB/s  eta 30s
# 22% [=======>                               ] 6.798.240   1,21MB/s  eta 30s
# 22% [=======>                               ] 7.051.680   1,21MB/s  eta 30s
# 23% [========>                              ] 7.305.120   1,21MB/s  eta 27s
# 24% [========>                              ] 7.564.320   1,21MB/s  eta 27s
# 25% [========>                              ] 7.810.560   1,21MB/s  eta 27s
# 26% [=========>                             ] 8.068.320   1,21MB/s  eta 27s
# 27% [=========>                             ] 8.327.520   1,21MB/s  eta 27s
# 27% [=========>                             ] 8.573.760   1,21MB/s  eta 24s
# 28% [==========>                            ] 8.832.960   1,21MB/s  eta 24s
# 29% [==========>                            ] 9.090.720   1,21MB/s  eta 24s
# 30% [==========>                            ] 9.338.400   1,21MB/s  eta 24s
# 31% [===========>                           ] 9.596.160   1,21MB/s  eta 24s
# 32% [===========>                           ] 9.855.360   1,21MB/s  eta 22s
# 32% [===========>                           ] 10.101.600  1,21MB/s  eta 22s
# 33% [============>                          ] 10.360.800  1,21MB/s  eta 22s
# 34% [============>                          ] 10.620.000  1,21MB/s  eta 22s
# 35% [============>                          ] 10.867.680  1,21MB/s  eta 22s
# 36% [=============>                         ] 11.125.440  1,21MB/s  eta 20s
# 36% [=============>                         ] 11.384.640  1,21MB/s  eta 20s
# 37% [=============>                         ] 11.630.880  1,21MB/s  eta 20s
# 38% [==============>                        ] 11.890.080  1,21MB/s  eta 20s
# 39% [==============>                        ] 12.147.840  1,21MB/s  eta 20s
# 40% [==============>                        ] 12.405.600  1,21MB/s  eta 18s
# 41% [===============>                       ] 12.651.840  1,21MB/s  eta 18s
# 41% [===============>                       ] 12.909.600  1,21MB/s  eta 18s
# 42% [===============>                       ] 13.167.360  1,21MB/s  eta 18s
# 43% [===============>                       ] 13.413.600  1,21MB/s  eta 18s
# 44% [================>                      ] 13.672.800  1,21MB/s  eta 17s
# 45% [================>                      ] 13.932.000  1,21MB/s  eta 17s
# 46% [================>                      ] 14.189.760  1,21MB/s  eta 17s
# 46% [=================>                     ] 14.438.880  1,21MB/s  eta 17s
# 47% [=================>                     ] 14.692.320  1,21MB/s  eta 17s
# 48% [=================>                     ] 14.951.520  1,21MB/s  eta 15s
# 49% [==================>                    ] 15.210.720  1,21MB/s  eta 15s
# 50% [==================>                    ] 15.464.160  1,21MB/s  eta 15s
# 51% [==================>                    ] 15.717.600  1,21MB/s  eta 15s
# 51% [===================>                   ] 15.972.480  1,21MB/s  eta 15s
# 52% [===================>                   ] 16.230.240  1,21MB/s  eta 14s
# 53% [===================>                   ] 16.483.680  1,21MB/s  eta 14s
# 54% [====================>                  ] 16.737.120  1,21MB/s  eta 14s
# 55% [====================>                  ] 16.996.320  1,21MB/s  eta 14s
# 56% [====================>                  ] 17.254.080  1,21MB/s  eta 14s
# 56% [=====================>                 ] 17.508.960  1,22MB/s  eta 12s
# 57% [=====================>                 ] 17.762.400  1,21MB/s  eta 12s
# 58% [=====================>                 ] 18.014.400  1,21MB/s  eta 12s
# 59% [======================>                ] 18.273.600  1,21MB/s  eta 12s
# 60% [======================>                ] 18.531.360  1,21MB/s  eta 12s
# 61% [======================>                ] 18.784.800  1,22MB/s  eta 11s
# 61% [=======================>               ] 19.038.240  1,21MB/s  eta 11s
# 62% [=======================>               ] 19.291.680  1,21MB/s  eta 11s
# 63% [=======================>               ] 19.549.440  1,21MB/s  eta 11s
# 64% [========================>              ] 19.805.760  1,22MB/s  eta 11s
# 64% [========================>              ] 19.866.240   952KB/s  eta 11s
# 64% [========================>              ] 19.933.920   910KB/s  eta 11s
# 66% [========================>              ] 20.357.280   952KB/s  eta 11s
# 67% [=========================>             ] 20.816.192  1001KB/s  eta 11s
# 68% [=========================>             ] 21.219.392  1,00MB/s  eta 11s
# 69% [==========================>            ] 21.494.880  1,01MB/s  eta 9s
# 73% [===========================>           ] 22.653.088  1,22MB/s  eta 9s
# 74% [============================>          ] 22.912.288  1,22MB/s  eta 9s
# 75% [============================>          ] 23.170.048  1,22MB/s  eta 9s
# 76% [============================>          ] 23.429.248  1,22MB/s  eta 9s
# 76% [============================>          ] 23.678.368  1,22MB/s  eta 6s
# 77% [=============================>         ] 23.936.128  1,22MB/s  eta 6s
# 78% [=============================>         ] 24.195.328  1,22MB/s  eta 6s
# 79% [=============================>         ] 24.453.088  1,22MB/s  eta 6s
# 80% [==============================>        ] 24.706.528  1,22MB/s  eta 6s
# 81% [==============================>        ] 24.964.288  1,22MB/s  eta 5s
# 81% [==============================>        ] 25.219.168  1,67MB/s  eta 5s
# 82% [===============================>       ] 25.476.928  1,62MB/s  eta 5s
# 83% [===============================>       ] 25.734.688  1,57MB/s  eta 5s
# 84% [===============================>       ] 25.993.888  1,51MB/s  eta 5s
# 85% [================================>      ] 26.245.888  1,51MB/s  eta 4s
# 86% [================================>      ] 26.499.328  1,22MB/s  eta 4s
# 86% [================================>      ] 26.758.528  1,22MB/s  eta 4s
# 87% [=================================>     ] 27.017.728  1,22MB/s  eta 4s
# 88% [=================================>     ] 27.194.848   954KB/s  eta 3s
# 88% [=================================>     ] 27.270.720   912KB/s  eta 3s
# 89% [==================================>    ] 27.645.120   945KB/s  eta 3s
# 91% [==================================>    ] 28.051.648   981KB/s  eta 3s
# 91% [==================================>    ] 28.213.472   934KB/s  eta 3s
# 96% [====================================>  ] 29.817.088  1,22MB/s  eta 1s
# 97% [=====================================> ] 30.070.528  1,22MB/s  eta 1s
# 98% [=====================================> ] 30.329.728  1,22MB/s  eta 1s
# 99% [=====================================> ] 30.588.704  1,22MB/s  eta 1s
# 100%[======================================>] 30.793.412  1,22MB/s   in 27s
# 2013-10-27 00:20:09 (1,10 MB/s) - ‘air.sig995.2012.nc’ saved [30793412]

# %% [markdown]
# Create file id:

# %%
fnc = netcdf.netcdf_file('air.sig995.2012.nc')

# %% [markdown]
# It's not really file id, it's *netcdf_file* object, that have some methods and attributes:

# %%
fnc.description
# Out:
# 'Data is from NMC initialized reanalysis\n(4x/day).  These are the 0.9950 sigma level values.'

# %%
fnc.history
# Out:
# 'created 2011/12 by Hoop (netCDF2.3)'

# %% [markdown]
# list variables

# %%
fnc.variables
# Out:
# {'air': <scipy.io.netcdf.netcdf_variable at 0xb66140c>,
#  'lat': <scipy.io.netcdf.netcdf_variable at 0xb66172c>,
#  'lon': <scipy.io.netcdf.netcdf_variable at 0xb66162c>,
#  'time': <scipy.io.netcdf.netcdf_variable at 0xb6614ec>}

# %% [markdown]
# Access information about variables

# %%
air = fnc.variables['air']

# %% [markdown]
# This time we create *netcdf_variable* object, that contain among other things attributes of the netCDF variable as well as data themselves.

# %%
air.actual_range
# Out:
# array([ 191.1000061,  323.       ], dtype=float32)

# %%
air.long_name
# Out:
# '4xDaily Air temperature at sigma level 995'

# %%
air.units
# Out:
# 'degK'

# %%
print(air.add_offset)
print(air.scale_factor)
# Out:
# 512.81
# 0.01

# %%
air.shape
# Out:
# (1464, 73, 144)

# %% [markdown]
# We can access the data by simply using array syntax. Here we show first time step of our data set:

# %%
imshow(air[0,:,:])
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xbb6972c>

# %% [markdown]
# Data are packed. In order to unpack we have to use *scale_factor* and *add_offset* values from attributes of the netCDF *air* variable. We also convert to $^{\circ}$C:

# %%
air_c = ((air[:] * air.scale_factor) + air.add_offset) - 273.15

# %% [markdown]
# Check the values of our new variable:

# %%
imshow(air_c[0,:,:])
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xbd5ab6c>

# %% [markdown]
# ### Save netCDF file

# %% [markdown]
# Minimalistic variant :)

# %%
# !rm test_netcdf.nc
fw = netcdf.netcdf_file('test_netcdf.nc', 'w')

fw.createDimension('t', 1464)
fw.createDimension('y', 73)
fw.createDimension('x', 144)

air_var = fw.createVariable( 'air','float32', ('t', 'y', 'x'))
air_var[:] = air_c[:]
fw.close()

# %% [markdown]
# More descriptive variant:

# %%
# !rm test_netcdf.nc
fw = netcdf.netcdf_file('test_netcdf.nc', 'w')

fw.createDimension('TIME', 1464)
fw.createDimension('LATITUDE', 73)
fw.createDimension('LONGITUDE', 144)

time = fw.createVariable('TIME', 'f', ('TIME',))
time[:] = fnc.variables['time'][:]
time.units = 'hours since 1-1-1 00:00:0.0' 

lat  = fw.createVariable('LATITUDE', 'f', ('LATITUDE',))
lat[:] = fnc.variables['lat'][:]

lon = fw.createVariable('LONGITUDE', 'f', ('LONGITUDE',))
lon[:] = fnc.variables['lon'][:]

ha = fw.createVariable('New_air','f', ('TIME', 'LATITUDE', 'LONGITUDE'))
ha[:] = air_c[:]
ha.missing_value = -9999.

fw.close()

# %% [markdown]
# ## Links

# %% [markdown]
# * [PyNio - library that reads NetCDF, GRIB, HDF and so on ... ](http://www.pyngl.ucar.edu/Nio.shtml)
# * [netCDF4 - advanced netCDF module](http://netcdf4-python.googlecode.com/svn/trunk/docs/netCDF4-module.html)
# * [Scipy cookbook](http://wiki.scipy.org/Cookbook)
